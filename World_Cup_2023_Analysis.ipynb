# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaythakur3369/Mentorness-Internship/blob/main/World_Cup_2023_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name - World Cup 2023 Analysis**
# ## **Developed By - Ajay Thakur (ajaythakur3369@gmail.com)**
# ## **Branch Name - Electronics and Communication Engineering**
# ## **Institute Name - Indian Institute of Information Technology Kota**
# ## **Submitted To - Mentorness**
# ## **Project Link (GitHub) - [Click here](https://github.com/ajaythakur3369/Mentorness-Internship)**

# %% [markdown]
# # **Problem Statement -**

# %% [markdown]
# Perform a detailed exploratory data analysis on the World Cup 2023 dataset. The goal is to uncover patterns, trends, and notable statistics that provide a comprehensive understanding of team and player performance.

# %% [markdown]
# # **Let's Begin !**

# %% [markdown]
# **Import Libraries**

# %%
# Importing necessary libraries for data analysis and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Accessing the Drive from Colab to access the file
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Reading the data from "World_Cup_dataset.csv" into the 'World_cup' DataFrame
World_cup = pd.read_csv("/content/drive/MyDrive/Colab_Notebook/Internship_Name/Mentorness/File_Name/World_Cup_dataset.csv")

# Reading the data from "Results_dataset.csv" into the 'results' DataFrame
results = pd.read_csv("/content/drive/MyDrive/Colab_Notebook/Internship_Name/Mentorness/File_Name/Results_dataset.csv")

# %%
# Displaying the first few rows of the World_cup DataFrame
World_cup
# Out:
#       Team_name  Team_ranking  Titles  Win_percentage_ODI  WC_matches  \
# 0     Australia             1       5               60.73          94
# 1      Pakistan             2       1               52.78          79
# 2         India             3       2               52.38          84
# 3  New Zealand              4       0               45.89          89
# 4       England             5       1               50.32          83
# 5  South Africa             6       0               61.00          64
# 6    Bangladesh             7       0               36.65          40
# 7   Afghanistan             8       0               49.65          15
# 8     Sri Lanka             9       1               45.74          80
# 9   Netherlands            10       0               34.21          20
#
#    WC_match_won  Win_percent_WC  WC_match_loss  Loss_percent_WC  Tied  \
# 0            69           73.40             23            24.46     1
# ...

# %% [markdown]
# **Number of Titles Won by each Team**

# %%
# Setting the figure size using sns.set
sns.set(rc = {'figure.figsize':(15, 6)})
colors = sns.color_palette("muted")

# Creating a bar plot using sns.barplot to visualize team titles
ax = sns.barplot(x = 'Team_name', y = 'Titles', data = World_cup, palette = colors, width = 0.4)
for g in ax.patches:
    ax.annotate(format(g.get_height(), '0.0f'), (g.get_x() + g.get_width()/2, g.get_height()), ha = 'center', va = 'center',
                xytext = (0, 9), textcoords = 'offset points', fontname = 'serif')
ax.patch.set_facecolor('aliceblue')

plt.grid(True, color = "grey", linewidth = "0.4")
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("Titles", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Team Name vs. Titles", fontname = 'serif', fontsize = 16)

# Display the plot
plt.show()

# %% [markdown]
# **Winning Percentage in the World Cup by each Team**

# %%
# Setting the figure size for the bar plot using Seaborn
sns.set(rc = {'figure.figsize':(15, 6)})
colors = sns.color_palette("muted")

# Create a bar plot using Seaborn
ax = sns.barplot(x = 'Team_name', y = 'Win_percentage_ODI', data = World_cup, palette = colors, width = 0.4)
for g in ax.patches:
    ax.annotate(format(g.get_height(), '0.2f'), (g.get_x() + g.get_width()/2, g.get_height()), ha = 'center', va = 'center',
                xytext = (0, 9), textcoords = 'offset points', fontname = 'serif')
ax.patch.set_facecolor('aliceblue')

plt.grid(True, color = "grey", linewidth = "0.4")
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("Winning Percentage in the World Cup", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Team Name vs. Winning Percentage in the World Cup", fontname = 'serif', fontsize = 16)

# Display the plot
plt.show()

# %% [markdown]
# **Number of Matches Won in the World Cup by each Team**

# %%
# Setting the figure size for the bar plot using Seaborn
sns.set(rc = {'figure.figsize':(15, 6)})
colors = sns.color_palette("muted")

# Create a bar plot using Seaborn
ax = sns.barplot(x = 'Team_name', y = 'WC_match_won', data = World_cup, palette = colors, width = 0.4)
for g in ax.patches:
    ax.annotate(format(g.get_height(), '0.0f'), (g.get_x() + g.get_width()/2, g.get_height()), ha = 'center', va = 'center',
                xytext = (0, 9), textcoords = 'offset points', fontname = 'serif')
ax.patch.set_facecolor('aliceblue')

plt.grid(True, color = "grey", linewidth = "0.4")
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("Winning Matches in the World Cup", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Team Name vs. Winning Matches in the World Cup", fontname = 'serif', fontsize = 16)

# Display the plot
plt.show()

# %% [markdown]
# **Recent ICC ODI (World Cup) Rating**

# %%
# Setting the figure size for the bar plot using Seaborn
sns.set(rc = {'figure.figsize':(15, 6)})
colors = sns.color_palette("muted")

# Creating a bar plot using Seaborn to display recent ratings of teams
ax = sns.barplot(x = 'Team_name', y = 'Rating', data = World_cup, palette = colors, width = 0.4)
for g in ax.patches:
    ax.annotate(format(g.get_height(), '0.0f'), (g.get_x() + g.get_width()/2, g.get_height()), ha = 'center', va = 'center',
                xytext = (0, 9), textcoords = 'offset points', fontname = 'serif')
ax.patch.set_facecolor('aliceblue')

plt.grid(True, color = "grey", linewidth = "0.4")
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("Rating", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Team Name vs. Rating", fontname = 'serif', fontsize = 16)

# Display the plot
plt.show()

# %%
# Displaying the first few rows of the results DataFrame
results.head()
# Out:
#          Date       Team_1    Team_2       Winner            Margin  \
# 0  17/04/2015  Bangladesh   Pakistan  Bangladesh     won by 79 runs
# 1  19/04/2015  Bangladesh   Pakistan  Bangladesh   won by 7 wickets
# 2  22/04/2015  Bangladesh   Pakistan  Bangladesh   won by 8 wickets
# 3  08/05/2015     Ireland    England    No result         No result
# 4  26/05/2015    Pakistan   Zimbabwe    Pakistan     won by 41 runs
#
#                           Ground
# 0  Shere Bangla National Stadium
# 1  Shere Bangla National Stadium
# 2  Shere Bangla National Stadium
# 3                    The Village
# 4                Gaddafi Stadium

# %%
# Removing rows with 'Match abandoned' and 'No result' from the 'results' DataFrame
results.drop(results[(results['Winner'] == 'Match abandoned' )].index, inplace = True)
results.drop(results[(results['Winner'] == 'No result' )].index, inplace = True)

# %% [markdown]
# **Stats of the top 5 teams in the World Cup 2023**

# %% [markdown]
# **1. Stats of the Indian Team**

# %%
# Filtering the 'results' DataFrame to include rows where India played either as Team_1 or Team_2
df = results[(results['Team_1'] == 'India') | (results['Team_2'] == 'India')]

# Creating a new DataFrame 'India' containing all rows from the filtered DataFrame
India = df.iloc[:]

# Displaying the first few rows of the 'India' DataFrame
India.head()
# Out:
#           Date       Team_1 Team_2       Winner            Margin  \
# 11  18/06/2015   Bangladesh  India  Bangladesh     won by 79 runs
# 13  21/06/2015  Bangladesh   India  Bangladesh   won by 6 wickets
# 14  24/06/2015  Bangladesh   India        India    won by 77 runs
# 16  10/07/2015    Zimbabwe   India        India     won by 4 runs
# 19  12/07/2015    Zimbabwe   India        India    won by 62 runs
#
#                            Ground
# 11  Shere Bangla National Stadium
# 13  Shere Bangla National Stadium
# 14  Shere Bangla National Stadium
# 16             Harare Sports Club
# 19             Harare Sports Club

# %%
# Filtering the 'India' dataframe to create a new dataframe 'India_win' containing rows where the 'Winner' column is 'India'
India_win = India[India['Winner'] == 'India']

# %%
India_win
# Out:
#            Date         Team_1        Team_2 Winner             Margin  \
# 14   24/06/2015    Bangladesh          India  India     won by 77 runs
# 16   10/07/2015      Zimbabwe          India  India      won by 4 runs
# 19   12/07/2015      Zimbabwe          India  India     won by 62 runs
# 20   14/07/2015      Zimbabwe          India  India     won by 83 runs
# 73   23/01/2016     Australia          India  India   won by 6 wickets
# 87   11/06/2016       Zimbabwe         India  India   won by 9 wickets
# 89   13/06/2016      Zimbabwe          India  India   won by 8 wickets
# 91   15/06/2016      Zimbabwe          India  India  won by 10 wickets
# 141  23/10/2016          India   New Zealand  India   won by 7 wickets
# 288  01/02/2018  South Africa          India  India   won by 6 wickets
# 289  04/02/2018  South Africa          India  India   won by 9 wickets
# 290  07/02/2018  South Africa          India  India    won by 124 runs
# ...

# %% [markdown]
# **Number of Wins in the World Cup against other Teams**

# %%
# Excluding Team India's name
excluded_value = 'India'

# Filtering out rows with the excluded value
filtered_df = India_win[India_win['Team_2'] != excluded_value]

# Counting the occurrences of each value in the filtered DataFrame's 'Team_2' column
value_counts = filtered_df['Team_2'].value_counts()

# Print the value counts
print(value_counts)
# Out:
# Team_2
# West Indies     6
# New Zealand     4
# Australia       3
# Sri Lanka       3
# England         2
# South Africa    2
# Name: count, dtype: int64

# %%
# Excluding Team India's name
excluded_value = 'India'

# Filtering out rows with the excluded value
filtered_df = India_win[India_win['Team_1'] != excluded_value]

# Counting the occurrences of each value in the filtered DataFrame's 'Team_2' column
value_counts = filtered_df['Team_1'].value_counts()

# Print the value counts
print(value_counts)
# Out:
# Team_1
# Zimbabwe         5
# South Africa     5
# West Indies      5
# Bangladesh       4
# Zimbabwe         4
# Australia        2
# Sri Lanka        2
# England          2
# England          1
# Hong Kong        1
# New Zealand      1
# Afghanistan      1
# Australia        1
# Bangladesh       1
# Name: count, dtype: int64

# %% [markdown]
# **Display Team India's Victories against other Teams using the Bar Graph**

# %%
# Exclude Team India from the display
exclude = 'India'

# Filter out the opponent to be excluded from the data
filtered_data = India_win[India_win['Team_2'] != exclude]

# Plot a bar chart to display the top 5 opponents faced by India
plt.figure(figsize = (15, 6))
plt.grid(True, color = "grey", linewidth = "0.4")
plt.bar(list(filtered_data['Team_2'].value_counts()[0:5].keys()), list(filtered_data['Team_2'].value_counts()[0:5]), color = "b", width = 0.22)
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("India's Victories", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Team Name vs. India's victories against Team_2", fontname = 'serif', fontsize = 16)
plt.show()

# %%
# Exclude Team India from consideration
exclude = 'India'

# Filter out the opponent to be excluded from the dataset
filtered_data = India_win[India_win['Team_1'] != exclude]

# Plot a bar chart to display the top 5 opponents faced by India
plt.figure(figsize = (15, 6))
plt.grid(True, color = "grey", linewidth = "0.4")
plt.bar(list(filtered_data['Team_1'].value_counts()[0:5].keys()), list(filtered_data['Team_1'].value_counts()[0:5]), color = "b", width = 0.22)
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("India's Victories", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Team Name vs. India's victories against Team_1", fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# **India's Winning Percentage against each Team**

# %%
# The number of wins against each team
# Out of the 1032 ODI matches played by India, the number of matches won against each of the following teams is...
team_win_counts = {
    'Australia': 54,
    'New Zealand': 58,
    'South Africa ': 37,
    'Pakistan': 	55,
    'Sri Lanka': 93,
    'Bangladesh': 30,
    'England': 57,
    'Netherlands': 2,
    'Afghanistan': 3
}

# The total number of matches played is calculated
total_matches = sum(team_win_counts.values())

# India's win percentages against each team are calculated
win_percentages = {team: (wins / total_matches) * 100 for team, wins in team_win_counts.items()}

# %%
# Pie chart
plt.figure(figsize = (6, 6))
plt.pie(win_percentages.values(), labels = win_percentages.keys(), autopct = '%1.1f%%', startangle = 195, textprops = {'fontname': 'serif','fontsize': 12})

# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')

# Title for the pie chart
plt.title('Winning Percentage of India against each Team', fontname = 'serif', fontsize = 13)

# Display the pie chart
plt.show()

# %% [markdown]
# **Winning Percentage of India in the World Cup**

# %%
# Number of wins against each team in the ODI World Cup
# Out of the 84 ODI matches played by India in the ODI World Cup, the number of matches won against each of the following teams is...
team_win_counts_wc_ind = {
    'Australia': 4,
    'New Zealand': 3,
    'South Africa ': 2,
    'Pakistan': 7,
    'Sri Lanka': 5,
    'Bangladesh': 3,
    'England': 3,
    'Netherlands': 2,
    'Afghanistan': 2
}

# The total number of matches played is calculated
total_matches_wc_ind = sum(team_win_counts_wc_ind.values())

# India's win percentages against each team are calculated
win_percentages_wc_ind = {team: (wins / total_matches_wc_ind) * 100 for team, wins in team_win_counts_wc_ind.items()}

# %%
# Pie chart
plt.figure(figsize = (6, 6))
plt.pie(win_percentages_wc_ind.values(), labels = win_percentages_wc_ind.keys(), autopct = '%1.1f%%', startangle = 140, textprops = {'fontname': 'serif', 'fontsize': 12})

# Ensuring an equal aspect ratio guarantees that the pie is drawn as a circle
plt.axis('equal')

# Title for the pie chart
plt.title("India's Winning Percentage in the World Cup", fontname = 'serif', fontsize = 13)

# Display the pie chart
plt.show()

# %% [markdown]
# **2. Stats of the Australian Team**

# %%
# Filter the 'results' DataFrame to include rows where Australia played as either Team_1 or Team_2
df1 = results[(results['Team_1'] == 'Australia') | (results['Team_2'] == 'Australia')]

# Create a new DataFrame named 'Australia' containing all rows from the filtered DataFrame
Australia = df1.iloc[:]

# Show the first few rows of the 'Australia' DataFrame
Australia.head()
# Out:
#           Date    Team_1     Team_2      Winner            Margin  \
# 32  27/08/2015  Ireland   Australia  Australia     won by 23 runs
# 33  03/09/2015  England   Australia  Australia     won by 59 runs
# 34  05/09/2015  England   Australia  Australia     won by 64 runs
# 35  08/09/2015   England  Australia     England    won by 93 runs
# 36  11/09/2015  England   Australia     England  won by 3 wickets
#
#                         Ground
# 32  Civil Service Cricket Club
# 33               The Rose Bowl
# 34                      Lord's
# 35                Old Trafford
# 36                  Headingley

# %%
# Filter the 'Australia' DataFrame to create a new DataFrame named 'Australia_win', including only the rows where the 'Winner' column is 'Australia'
Australia_win = Australia[Australia['Winner'] == 'Australia']

# %%
Australia_win
# Out:
#            Date        Team_1        Team_2     Winner             Margin  \
# 37   12/09/2015      England      Australia  Australia   won by 8 wickets
# 79   06/02/2016  New Zealand      Australia  Australia   won by 4 wickets
# 85   05/06/2016  West Indies      Australia  Australia   won by 6 wickets
# 88   11/06/2016     Australia  South Africa  Australia     won by 36 runs
# 97   21/06/2016  West Indies      Australia  Australia   won by 6 wickets
# 101  26/06/2016  West Indies      Australia  Australia     won by 58 runs
# 113  21/08/2016    Sri Lanka      Australia  Australia   won by 3 wickets
# 117  28/08/2016    Sri Lanka      Australia  Australia   won by 2 wickets
# 119  31/08/2016    Sri Lanka      Australia  Australia   won by 6 wickets
# 122  04/09/2016    Sri Lanka      Australia  Australia   won by 5 wickets
# 161  19/01/2017     Australia      Pakistan  Australia   won by 7 wickets
# 163  22/01/2017     Australia      Pakistan  Australia     won by 86 runs
# ...

# %% [markdown]
# **Counting the Number of Wins for Australia against other Teams**

# %%
# Exclude the name of Team Australia
excluded_value = 'Australia'

# Filter out rows containing the excluded value
filtered_df = Australia_win[Australia_win['Team_2'] != excluded_value]

# Count the occurrences of each value in the 'Team_2' column of the filtered DataFrame
value_counts = filtered_df['Team_2'].value_counts()

# Print the counts of each value
print(value_counts)
# Out:
# Team_2
# England         4
# New Zealand     4
#  Pakistan       2
# India           2
# Zimbabwe        2
# South Africa    1
# Pakistan        1
# Name: count, dtype: int64

# %%
# Omit the name of Team Australia
excluded_value = 'Australia'

# Filtering out rows containing the excluded value
filtered_df = Australia_win[Australia_win['Team_1'] != excluded_value]

# Count the occurrences of each value in the 'Team_2' column of the filtered DataFrame
value_counts = filtered_df['Team_1'].value_counts()

# Print the counts of each value
print(value_counts)
# Out:
# Team_1
# Sri Lanka       4
# Pakistan        4
# West Indies     3
# India           3
# England         2
# Pakistan        2
# England         2
# West Indies     2
# Sri Lanka       2
# India           2
# New Zealand     1
# Afghanistan     1
# Name: count, dtype: int64

# %% [markdown]
# **Display Team Australia's Winnings against other Teams using a Bar Graph**

# %%
# Omit Team Australia
exclude = 'Australia'

# Filter out the opponent to be excluded from the data
filtered_data = Australia_win[Australia_win['Team_2'] != exclude]

# Plotting a bar chart to display the top 5 opponents faced by Australia
plt.figure(figsize = (15, 6))
plt.grid(True, color = "grey", linewidth = "0.4")
plt.bar(list(filtered_data['Team_2'].value_counts()[0:5].keys()), list(filtered_data['Team_2'].value_counts()[0:5]), color = "y", width = 0.22)
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("Australia's winnings", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("A comparison of Australia's winnings against each team listed in the 'Team_2' column", fontname = 'serif', fontsize = 16)
plt.show()

# %%
# Remove Team Australia
exclude = 'Australia'

# Filter out the opponent to be excluded from the dataset
filtered_data = Australia_win[Australia_win['Team_1'] != exclude]

# Create a bar chart illustrating the top 5 opponents Australia has faced
plt.figure(figsize = (15, 6))
plt.grid(True, color = "grey", linewidth = "0.4")
plt.bar(list(filtered_data['Team_1'].value_counts()[0:5].keys()), list(filtered_data['Team_1'].value_counts()[0:5]), color = "y", width = 0.22)
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("Australia's winnings", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Comparison of Australia's winnings against each team listed in the 'Team_1' column", fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# **The Winning Percentage of Australia against each Team**

# %%
# The number of wins against each team
# Out of the 978 ODI matches played by Australia, the number of matches won against the following teams is
team_win_counts = {
    'India': 82,
    'New Zealand': 95,
    'South Africa ': 48,
    'Pakistan': 69,
    'Sri Lanka': 63,
    'Bangladesh': 19,
    'England': 87,
    'Netherlands': 2,
    'Afghanistan': 3
}

# The total number of matches played is calculated
total_matches = sum(team_win_counts.values())

# The win percentages of Australia against each team are calculated
win_percentages = {team: (wins / total_matches) * 100 for team, wins in team_win_counts.items()}

# %%
# Pie chart
plt.figure(figsize = (6, 6))
plt.pie(win_percentages.values(), labels = win_percentages.keys(), autopct = '%1.1f%%', startangle = 155, textprops = {'fontname': 'serif','fontsize': 12})

# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')

# Title of the pie chart
plt.title('Winning Percentage of Australia against each Team', fontname = 'serif', fontsize = 13)

# Display the pie chart
plt.show()

# %% [markdown]
# **The Winning Percentage of Australia in the World Cup**

# %%
# The number of wins against each team in the ODI World Cup
# Out of the 94 ODI matches played by Australia in the ODI World Cup, the number of matches won against the following teams is
team_win_counts_wc_aus = {
    'India': 8,
    'New Zealand': 8,
    'South Africa ': 3,
    'Pakistan': 6,
    'Sri Lanka': 8,
    'Bangladesh': 3,
    'England': 6,
    'Netherlands': 2,
    'Afghanistan': 2
}

# The total number of matches played is calculated
total_matches_wc_aus = sum(team_win_counts_wc_aus.values())

# The win percentages of Australia against each team are calculated
win_percentages_wc_aus = {team: (wins / total_matches_wc_aus) * 100 for team, wins in team_win_counts_wc_aus.items()}

# %%
# Pie chart
plt.figure(figsize = (6, 6))
plt.pie(win_percentages_wc_aus.values(), labels = win_percentages_wc_aus.keys(), autopct='%1.1f%%', startangle = 130, textprops = {'fontname': 'serif','fontsize': 12})

# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')

# Title of the pie chart
plt.title('The Winning Percentage of Australia in the World Cup', fontname = 'serif', fontsize = 13)

# Display the pie chart
plt.show()

# %% [markdown]
# **3. Stats of the Pakistan Team**

# %%
# Filter the 'results' DataFrame to include rows where Pakistan played as either Team_1 or Team_2
df2 = results[(results['Team_1'] == 'Pakistan') | (results['Team_2'] == 'Pakistan')]

# Create a new DataFrame called 'Pakistan' containing all rows from the filtered DataFrame
Pakistan = df2.iloc[:]

# Display the first few rows of the 'Pakistan' DataFrame
Pakistan.head()
# Out:
#           Date       Team_1    Team_2       Winner            Margin  \
# 0   17/04/2015  Bangladesh   Pakistan  Bangladesh     won by 79 runs
# 1   19/04/2015  Bangladesh   Pakistan  Bangladesh   won by 7 wickets
# 2   22/04/2015  Bangladesh   Pakistan  Bangladesh   won by 8 wickets
# 17  11/07/2015   Sri Lanka   Pakistan     Pakistan  won by 6 wickets
# 21  15/07/2015   Sri Lanka   Pakistan   Sri Lanka   won by 2 wickets
#
#                                      Ground
# 0             Shere Bangla National Stadium
# 1             Shere Bangla National Stadium
# 2             Shere Bangla National Stadium
# 17   Rangiri Dambulla International Stadium
# 21  Pallekele International Cricket Stadium

# %%
# Filtering the 'Pakistan' DataFrame to create a new DataFrame 'Pakistan_win' containing rows where the 'Winner' column is 'Pakistan'
Pakistan_win = Pakistan[Pakistan['Winner'] == 'Pakistan']

# %%
Pakistan_win
# Out:
#            Date         Team_1       Team_2    Winner             Margin  \
# 17   11/07/2015     Sri Lanka      Pakistan  Pakistan   won by 6 wickets
# 23   19/07/2015     Sri Lanka      Pakistan  Pakistan    won by 135 runs
# 24   22/07/2015     Sri Lanka      Pakistan  Pakistan   won by 7 wickets
# 38   01/10/2015      Zimbabwe      Pakistan  Pakistan    won by 131 runs
# 40   05/10/2015      Zimbabwe      Pakistan  Pakistan   won by 7 wickets
# 111  18/08/2016       Ireland      Pakistan  Pakistan    won by 255 runs
# 121  04/09/2016       England      Pakistan  Pakistan   won by 4 wickets
# 159  15/01/2017     Australia      Pakistan  Pakistan   won by 6 wickets
# 315  13/07/2018      Zimbabwe      Pakistan  Pakistan    won by 201 runs
# 317  16/07/2018      Zimbabwe      Pakistan  Pakistan   won by 9 wickets
# 319  18/07/2018      Zimbabwe      Pakistan  Pakistan   won by 9 wickets
# 320  20/07/2018      Zimbabwe      Pakistan  Pakistan    won by 244 runs
# ...

# %% [markdown]
# **The Number of Wins for Pakistan against other Teams**

# %%
# Exclude the name of Team Pakistan
excluded_value = 'Pakistan'

# Filtering out rows with the excluded value
filtered_df = Pakistan_win[Pakistan_win['Team_2'] != excluded_value]

# Counting the occurrences of each value in the 'Team_2' column of the filtered DataFrame
value_counts = filtered_df['Team_2'].value_counts()

# Print the value counts
print(value_counts)
# Out:
# Team_2
# New Zealand    5
# West Indies    3
# Sri Lanka      2
# Zimbabwe       2
# Australia      2
# Name: count, dtype: int64

# %%
# Omit the name of Team Pakistan
excluded_value = 'Pakistan'

# Filtering out rows containing the excluded value
filtered_df = Pakistan_win[Pakistan_win['Team_1'] != excluded_value]

# Counting the occurrences of each value in the 'Team_1' column of the filtered DataFrame
value_counts = filtered_df['Team_1'].value_counts()

# Print the value counts
print(value_counts)
# Out:
# Team_1
# Zimbabwe         7
# Sri Lanka        3
# Netherlands      3
# England          2
# Afghanistan      2
# South Africa     2
# Ireland          1
# Australia        1
# Hong Kong        1
# South Africa     1
# New Zealand      1
# Name: count, dtype: int64

# %% [markdown]
# **Displaying Team Pakistan's Winnings against other Teams using a Bar Graph**

# %%
# Exclude Team Pakistan
exclude = 'Pakistan'

# Filter out the opponent to be excluded from the data
filtered_data = Pakistan_win[Pakistan_win['Team_2'] != exclude]

# Plotting a bar chart to display the top 5 opponents faced by Pakistan
plt.figure(figsize = (15, 6))
plt.grid(True, color = "grey", linewidth = "0.4")
plt.bar(list(filtered_data['Team_2'].value_counts()[0:5].keys()), list(filtered_data['Team_2'].value_counts()[0:5]), color = "g", width = 0.22)
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("Pakistan's Winnings", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Comparison of Pakistan's Winnings against each Team listed in the 'Team_2' column", fontname = 'serif', fontsize = 16)
plt.show()

# %%
# Exclude Team Pakistan
exclude = 'Pakistan'

# Filter out the opponent to be excluded from the dataset
filtered_data = Pakistan_win[Pakistan_win['Team_1'] != exclude]

# Plotting a bar chart to display the top 5 opponents faced by Pakistan
plt.figure(figsize = (15, 6))
plt.grid(True, color = "grey", linewidth = "0.4")
plt.bar(list(filtered_data['Team_1'].value_counts()[0:5].keys()), list(filtered_data['Team_1'].value_counts()[0:5]), color = "g", width = 0.22)
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("Pakistan's Winnings", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Comparison of Pakistan's Winnings against each Team listed in the 'Team_1' column", fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# **The Winning Percentage of Pakistan against each Team**

# %%
# The number of wins against each team
# Out of the 945 ODI matches played by Pakistan, the number of matches won against the following teams is
team_win_counts = {
    'India': 73,
    'New Zealand': 60,
    'South Africa ': 30,
    'Australia': 34,
    'Sri Lanka': 92,
    'Bangladesh': 32,
    'England': 32,
    'Netherlands': 3,
    'Afghanistan': 7
}

# The total number of matches played is calculated
total_matches = sum(team_win_counts.values())

# The win percentages of Pakistan against each team are calculated
win_percentages = {team: (wins / total_matches) * 100 for team, wins in team_win_counts.items()}

# %%
# Pie chart
plt.figure(figsize = (6, 6))
plt.pie(win_percentages.values(), labels = win_percentages.keys(), autopct='%1.1f%%', startangle = 155, textprops = {'fontname': 'serif','fontsize': 12})

# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')

# Title of the pie chart
plt.title('The Winning Percentage of Pakistan against each Team', fontname = 'serif', fontsize = 13)

# Display the pie chart
plt.show()

# %% [markdown]
# **The Winning Percentage of Pakistan in the World Cup**

# %%
# The number of wins against each team in the ODI World Cup
# Out of the 79 ODI matches played by Pakistan in the ODI World Cup, the number of matches won against the following teams is
team_win_counts_wc_pak = {
    'India': 0,
    'New Zealand': 7,
    'South Africa ': 2,
    'Australia': 4,
    'Sri Lanka': 7,
    'Bangladesh': 1,
    'England': 5,
    'Afghanistan': 1
}

# The total number of matches played is calculated
total_matches_wc_pak = sum(team_win_counts_wc_pak.values())

# The win percentages of Pakistan against each team are calculated
win_percentages_wc_pak = {team: (wins / total_matches_wc_pak) * 100 for team, wins in team_win_counts_wc_pak.items()}

# %%
# Pie chart
plt.figure(figsize = (6, 6))
plt.pie(win_percentages_wc_pak.values(), labels = win_percentages_wc_pak.keys(), autopct = '%1.1f%%', startangle = 155, textprops = {'fontname': 'serif','fontsize': 12})

# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')

# Title of the pie chart
plt.title('Winning Percentage of Pakistan in the World Cup', fontname = 'serif', fontsize = 13)

# Display the pie chart
plt.show()

# %% [markdown]
# **4. Stats of the New Zealand Team**

# %%
# Filter the 'results' DataFrame to include rows where New Zealand played as either Team_1 or Team_2
df3 = results[(results['Team_1'] == 'New Zealand') | (results['Team_2'] == 'New Zealand')]

# Create a new DataFrame called 'New Zealand' containing all rows from the filtered DataFrame
New_Zealand = df3.iloc[:]

# Display the first few rows of the 'India' DataFrame
New_Zealand.head()
# Out:
#           Date    Team_1       Team_2        Winner            Margin  \
# 7   09/06/2015  England   New Zealand      England    won by 210 runs
# 8   12/06/2015   England  New Zealand  New Zealand     won by 13 runs
# 9   14/06/2015  England   New Zealand  New Zealand   won by 3 wickets
# 10  17/06/2015  England   New Zealand       England  won by 7 wickets
# 12  20/06/2015  England   New Zealand       England  won by 3 wickets
#
#               Ground
# 7          Edgbaston
# 8    Kennington Oval
# 9      The Rose Bowl
# 10      Trent Bridge
# 12  Riverside Ground

# %%
# Filtering the 'New Zealand' DataFrame to create a new DataFrame 'nz_win' containing rows where the 'Winner' column is 'New Zealand'
nz_win = New_Zealand[New_Zealand['Winner'] == 'New Zealand']

# %%
nz_win
# Out:
#            Date        Team_1        Team_2       Winner             Margin  \
# 27   04/08/2015     Zimbabwe    New Zealand  New Zealand  won by 10 wickets
# 28   07/08/2015     Zimbabwe    New Zealand  New Zealand     won by 38 runs
# 76   31/01/2016   New Zealand      Pakistan  New Zealand   won by 3 wickets
# 81   08/02/2016   New Zealand     Australia  New Zealand     won by 55 runs
# 140  20/10/2016        India    New Zealand  New Zealand      won by 6 runs
# 142  26/10/2016        India    New Zealand  New Zealand     won by 19 runs
# 154  26/12/2016   New Zealand    Bangladesh  New Zealand     won by 77 runs
# 200  14/05/2017      Ireland    New Zealand  New Zealand     won by 51 runs
# 271  06/01/2018   New Zealand      Pakistan  New Zealand     won by 61 runs
# 365  07/11/2018      Pakistan   New Zealand  New Zealand     won by 47 runs
# 372  03/01/2019   New Zealand     Sri Lanka  New Zealand     won by 45 runs
# ...

# %% [markdown]
# **The number of Wins for New Zealand in the World Cup against other Teams**

# %%
# Exclude the name of Team New Zealand
excluded_value = 'New Zealand'

# Filtering out rows containing the excluded value
filtered_df = nz_win[nz_win['Team_2'] != excluded_value]

# Counting the occurrences of each value in the 'Team_2' column of the filtered DataFrame
value_counts = filtered_df['Team_2'].value_counts()

# Print the value counts
print(value_counts)
# Out:
# Team_2
# Bangladesh      5
# India           4
# Sri Lanka       3
# Netherlands     3
# Pakistan        2
# Australia       1
# South Africa    1
# Name: count, dtype: int64

# %%
# Omit the name of Team New Zealand
excluded_value = 'New Zealand'

# Filtering out rows containing the excluded value
filtered_df = nz_win[nz_win['Team_1'] != excluded_value]

# Counting the occurrences of each value in the 'Team_2' column of the filtered DataFrame
value_counts = filtered_df['Team_1'].value_counts()

# Print the value counts
print(value_counts)
# Out:
# Team_1
# India           3
# Pakistan        3
# Ireland         3
# Zimbabwe        2
# West Indies     2
# Ireland         1
# Bangladesh      1
# Afghanistan     1
# Scotland        1
# Name: count, dtype: int64

# %% [markdown]
# **Displaying Team New Zealand's Winnings against other Teams using a Bar Graph**

# %%
# Exclude Team New Zealand
exclude = 'New Zealand'

# Filter out the opponent to be excluded from the data
filtered_data = nz_win[nz_win['Team_2'] != exclude]

# Plotting a bar chart to display the top 5 opponents faced by New Zealand
plt.figure(figsize = (15, 6))
plt.grid(True, color = "grey", linewidth = "0.4")
plt.bar(list(filtered_data['Team_2'].value_counts()[0:5].keys()), list(filtered_data['Team_2'].value_counts()[0:5]), color = "black", width = 0.22)
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("New Zealand's Winnings", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Comparison of New Zealand's Winnings against each Team listed in the 'Team_2' column", fontname = 'serif', fontsize = 16)
plt.show()

# %%
# Exclude Team New Zealand
exclude = 'New Zealand'

# Filter out the opponent to be excluded from the dataset
filtered_data = nz_win[nz_win['Team_1'] != exclude]

# Plotting a bar chart to display the top 5 opponents faced by New Zealand
plt.figure(figsize = (15, 6))
plt.grid(True, color = "grey", linewidth = "0.4")
plt.bar(list(filtered_data['Team_1'].value_counts()[0:5].keys()), list(filtered_data['Team_1'].value_counts()[0:5]), color = "black", width = 0.22)
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("New Zealand's Winnings", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Comparison of New Zealand's Winnings against each Team listed in the 'Team_1' column", fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# **The Winning Percentage of New Zealand against each Team**

# %%
# The number of wins against each team
# Out of the 794 ODI matches played by New Zealand, the number of matches won against the following teams is
team_win_counts = {
    'Australia': 39,
    'India': 50,
    'South Africa ': 26,
    'Pakistan': 50,
    'Sri Lanka': 49,
    'Bangladesh':28,
    'England': 42,
    'Netherlands': 4,
    'Afghanistan': 2
}

# The total number of matches played is calculated
total_matches = sum(team_win_counts.values())

# The win percentages of New Zealand against each team are calculated
win_percentages = {team: (wins / total_matches) * 100 for team, wins in team_win_counts.items()}

# %%
# Pie chart
plt.figure(figsize = (6, 6))
plt.pie(win_percentages.values(), labels = win_percentages.keys(), autopct = '%1.1f%%', startangle = 155, textprops = {'fontname': 'serif','fontsize': 12})

# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')

# Title of the pie chart
plt.title('The Winning Percentage of New Zealand against each Team', fontname = 'serif', fontsize = 13)

# Display the pie chart
plt.show()

# %% [markdown]
# **The Winning Percentage of New Zealand in the World Cup**

# %%
# The number of wins against each team in the ODI World Cup
# Out of the 89 ODI matches played by New Zealand in the ODI World Cup, the number of matches won against the following teams is
team_win_counts_wc_nz = {
    'Australia': 3,
    'India': 5,
    'South Africa ': 5,
    'Pakistan': 2,
    'Sri Lanka': 5,
    'Bangladesh': 5,
    'England': 5,
    'Netherlands': 4,
    'Afghanistan': 2
}

# The total number of matches played is calculated
total_matches_wc_nz = sum(team_win_counts_wc_nz.values())

# The win percentages of New Zealand against each team are calculated
win_percentages_wc_nz = {team: (wins / total_matches_wc_nz) * 100 for team, wins in team_win_counts_wc_nz.items()}

# %%
# Pie chart
plt.figure(figsize = (6, 6))
plt.pie(win_percentages_wc_nz.values(), labels = win_percentages_wc_nz.keys(), autopct = '%1.1f%%', startangle = 150, textprops = {'fontname': 'serif','fontsize': 12})

# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')

# Title of the pie chart
plt.title('The Winning Percentage of New Zealand in the World Cup', fontname = 'serif', fontsize = 13)

# Display the pie chart
plt.show()

# %% [markdown]
# **5. Stats of the England Team**

# %%
# Filter the 'results' DataFrame to include rows where England played as either Team_1 or Team_2
df4 = results[(results['Team_1'] == 'England') | (results['Team_2'] == 'England')]

# Create a new DataFrame called 'England' containing all rows from the filtered DataFrame
England = df4.iloc[:]

# Display the first few rows of the 'England' DataFrame
England.head()
# Out:
#           Date     Team_1       Team_2        Winner  \
# 8   12/06/2015    England  New Zealand  New Zealand
# 35  08/09/2015    England    Australia       England
# 55  11/11/2015  Pakistan       England      Pakistan
# 57  13/11/2015  Pakistan       England      England
# 58  17/11/2015  Pakistan       England      England
#
#                        Margin                   Ground
# 8              won by 13 runs          Kennington Oval
# 35             won by 93 runs             Old Trafford
# 55  Pakistan won by 6 wickets     Sheikh Zayed Stadium
# 57     England won by 95 runs     Sheikh Zayed Stadium
# 58   England won by 6 wickets  Sharjah Cricket Stadium

# %%
# Filtering the 'England' DataFrame to create a new DataFrame 'England_win' containing rows where the 'Winner' column is 'England'
England_win = England[England['Winner'] == 'England']

# %%
England_win
# Out:
#            Date         Team_1        Team_2   Winner  \
# 35   08/09/2015        England     Australia  England
# 59   20/11/2015       Pakistan       England  England
# 78   03/02/2016  South Africa        England  England
# 80   06/02/2016  South Africa        England  England
# 134  07/10/2016    Bangladesh        England  England
# 137  12/10/2016    Bangladesh        England  England
# 185  09/03/2017   West Indies        England  England
# 274  14/01/2018     Australia        England  England
# 278  18/01/2018     Australia        England  England
# 281  21/01/2018     Australia        England  England
# 287  28/01/2018     Australia        England  England
# 300  28/02/2018    New Zealand       England  England
# 301  03/03/2018   New Zealand        England  England
# 304  10/03/2018   New Zealand        England  England
# 352  13/10/2018     Sri Lanka        England  England
# 353  17/10/2018     Sri Lanka        England  England
# ...

# %% [markdown]
# **The Number of Wins for England against other Teams**

# %%
# Exclude the name of Team England
excluded_value = 'England'

# Filtering out rows containing the excluded value
filtered_df = England_win[England_win['Team_2'] != excluded_value]

# Counting the occurrences of each value in the 'Team_2' column of the filtered DataFrame
value_counts = filtered_df['Team_2'].value_counts()

# Print the value counts
print(value_counts)
# Out:
# Team_2
# Pakistan        5
# Australia       2
# India           2
# New Zealand     2
# Ireland         2
# Sri Lanka       2
# West Indies     1
# South Africa    1
# Name: count, dtype: int64

# %%
# Exclude the name of Team England
excluded_value = 'England'

# Filtering out rows containing the excluded value
filtered_df = England_win[England_win['Team_1'] != excluded_value]

# Counting the occurrences of each value in the 'Team_1' column of the filtered DataFrame
value_counts = filtered_df['Team_1'].value_counts()

# Print the value counts
print(value_counts)
# Out:
# Team_1
# Australia        4
# Netherlands      3
# South Africa     2
# Bangladesh       2
# New Zealand      2
# Sri Lanka        2
# South Africa     2
# Bangladesh       2
# Pakistan         1
# West Indies      1
# New Zealand      1
# Sri Lanka        1
# Ireland          1
# India            1
# Name: count, dtype: int64

# %% [markdown]
# **Displaying Team England's Winnings against other Teams using a Bar Graph**

# %%
# Exclude the name of Team England
exclude = 'England'

# Filter out the opponent to be excluded from the data
filtered_data = England_win[England_win['Team_2'] != exclude]

# Plotting a bar chart to display the top 5 opponents faced by England
plt.figure(figsize = (15, 6))
plt.grid(True, color = "grey", linewidth = "0.4")
plt.bar(list(filtered_data['Team_2'].value_counts()[0:5].keys()), list(filtered_data['Team_2'].value_counts()[0:5]), color = "red", width = 0.22)
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("England's Winnings", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Comparison of England's Winnings against each Team listed in the 'Team_2' column", fontname = 'serif', fontsize = 16)
plt.show()

# %%
# Exclude the name of Team England
exclude = 'England'

# Filter out the opponent to be excluded from the data
filtered_data = England_win[England_win['Team_1'] != exclude]

# Plotting a bar chart to display the top 5 opponents faced by England
plt.figure(figsize = (15, 6))
plt.grid(True, color = "grey", linewidth = "0.4")
plt.bar(list(filtered_data['Team_1'].value_counts()[0:5].keys()), list(filtered_data['Team_1'].value_counts()[0:5]), color = "red", width = 0.22)
plt.xlabel("Team Name", fontname = 'serif', fontsize = 14)
plt.xticks(fontname = 'serif')
plt.ylabel("England's Winnings", fontname = 'serif', fontsize = 14)
plt.yticks(fontname = 'serif')
plt.title("Comparison of England's Winnings against each Team listed in the 'Team_1' column", fontname = 'serif', fontsize = 16)
plt.show()

# %% [markdown]
# **The Win Percentage of England against each Team**

# %%
# The number of wins against each team
# Out of the 775 ODI matches played by England, the number of matches won against the following teams is
team_win_counts = {
    'India': 44,
    'New Zealand': 42,
    'South Africa ': 29,
    'Australia': 63,
    'Sri Lanka': 38,
    'Bangladesh': 19,
    'Pakistan': 56,
    'Netherlands': 6,
    'Afghanistan': 2
}

# The total number of matches played is calculated
total_matches = sum(team_win_counts.values())

# The win percentages of England against each team are calculated
win_percentages = {team: (wins / total_matches) * 100 for team, wins in team_win_counts.items()}

# %%
# Pie chart
plt.figure(figsize = (6, 6))
plt.pie(win_percentages.values(), labels = win_percentages.keys(), autopct = '%1.1f%%', startangle = 155, textprops = {'fontname': 'serif','fontsize': 12})

# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')

# Title of the pie chart
plt.title('The Winning Percentage of England against each Team', fontname = 'serif', fontsize = 13)

# Display the pie chart
plt.show()

# %%
# The number of wins against each team in the ODI World Cup
# Out of the 83 ODI matches played by England in the ODI World Cup, the number of matches won against the following teams is
team_win_counts_wc_eng = {
    'Australia': 3,
    'India': 4,
    'South Africa ': 4,
    'Pakistan': 4,
    'Sri Lanka': 6,
    'Bangladesh': 5,
    'New Zealand': 5,
    'Netherlands': 4,
    'Afghanistan': 2
}

# The total number of matches played is calculated
total_matches_wc_eng = sum(team_win_counts_wc_eng.values())

# The win percentages of England against each team are calculated
win_percentages_wc_eng = {team: (wins / total_matches_wc_eng) * 100 for team, wins in team_win_counts_wc_eng.items()}

# %%
# Pie chart
plt.figure(figsize = (6, 6))
plt.pie(win_percentages_wc_eng.values(), labels = win_percentages_wc_eng.keys(), autopct = '%1.1f%%', startangle = 150, textprops = {'fontname': 'serif','fontsize': 12})

# An equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')

# Title of the pie chart
plt.title('The Winning Percentage of England in the World Cup', fontname = 'serif', fontsize = 13)

# Display the pie chart
plt.show()

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# This is a list of cricket teams participating in the World Cup
worldcup_teams = ['England', ' South Africa', '', 'West Indies',
            'Pakistan', 'New Zealand', 'Sri Lanka', 'Afghanistan',
            'Australia', 'Bangladesh', 'India']

# Filtering matches involving only teams in the 'worldcup_teams' list
# Extract matches with Team_1 in the 'worldcup_teams' list
df_teams_1 = results[results['Team_1'].isin(worldcup_teams)]
# Extract matches with Team_2 in the 'worldcup_teams' list
df_teams_2 = results[results['Team_2'].isin(worldcup_teams)]

# Combining the filtered DataFrames
# Concatenates the two data frames vertically
df_teams = pd.concat((df_teams_1, df_teams_2))

# Remove duplicate rows, if any
df_teams.drop_duplicates()

# Count the number of rows in the final dataframe
df_teams.count()
# Out:
# Date      748
# Team_1    748
# Team_2    748
# Winner    748
# Margin    748
# Ground    748
# dtype: int64

# %%
# Displaying the first few rows of the 'df_teams' DataFrame
df_teams.head()
# Out:
#           Date      Team_1       Team_2        Winner  \
# 8   12/06/2015     England  New Zealand  New Zealand
# 11  18/06/2015  Bangladesh        India   Bangladesh
# 35  08/09/2015     England    Australia       England
# 53  07/11/2015   Sri Lanka  West Indies     Sri Lanka
# 56  11/11/2015  Bangladesh     Zimbabwe    Bangladesh
#
#                        Margin                                   Ground
# 8              won by 13 runs                          Kennington Oval
# 11             won by 79 runs            Shere Bangla National Stadium
# 35             won by 93 runs                             Old Trafford
# 53   Sri Lanka won by 19 runs  Pallekele International Cricket Stadium
# 56  Bangladesh won by 61 runs            Shere Bangla National Stadium

# %%
# Removing unnecessary columns from 'df_teams' and displaying the first few rows of the updated DataFrame
df_teams_2019 = df_teams.drop(['Date', 'Margin', 'Ground'], axis = 1)
df_teams_2019.head()
# Out:
#         Team_1       Team_2        Winner
# 8      England  New Zealand  New Zealand
# 11  Bangladesh        India   Bangladesh
# 35     England    Australia       England
# 53   Sri Lanka  West Indies     Sri Lanka
# 56  Bangladesh     Zimbabwe    Bangladesh

# %%
df_teams_2019
# Out:
#           Team_1       Team_2        Winner
# 8        England  New Zealand  New Zealand
# 11    Bangladesh        India   Bangladesh
# 35       England    Australia       England
# 53     Sri Lanka  West Indies     Sri Lanka
# 56    Bangladesh     Zimbabwe    Bangladesh
# ..           ...          ...           ...
# 716   Bangladesh  Afghanistan   Afghanistan
# 718    Sri Lanka  West Indies     Sri Lanka
# 719   Bangladesh  Afghanistan   Afghanistan
# 720  Netherlands    Sri Lanka     Sri Lanka
# 721   Bangladesh  Afghanistan    Bangladesh
#
# [748 rows x 3 columns]

# %% [markdown]
# **Feature Selection**

# %%
# Reset the index of 'df_teams_2019' while dropping the old index
df_teams_2019 = df_teams_2019.reset_index(drop = True)

# Set a value of 1 in the 'winning_team' column for rows where the 'Winner' column is the same as the 'Team_1' column
df_teams_2019.loc[df_teams_2019.Winner == df_teams_2019.Team_1, 'winning_team'] = 1

# Set a value of 2 in the 'winning_team' column for rows where the 'Winner' column is the same as the 'Team_2' column
df_teams_2019.loc[df_teams_2019.Winner == df_teams_2019.Team_2, 'winning_team'] = 2

# Drop the 'winning_team' column from the DataFrame
df_teams_2019 = df_teams_2019.drop(['winning_team'], axis = 1)

# Display the first few rows of the modified DataFrame using df_teams_2019.head()
df_teams_2019.head()
# Out:
#        Team_1       Team_2        Winner
# 0     England  New Zealand  New Zealand
# 1  Bangladesh        India   Bangladesh
# 2     England    Australia       England
# 3   Sri Lanka  West Indies     Sri Lanka
# 4  Bangladesh     Zimbabwe    Bangladesh

# %% [markdown]
# **Training and Testing the Data**

# %%
# Importing train_test_split from sklearn.model_selection
from sklearn.model_selection import train_test_split

# %%
# Creating dummy variables for team names
final = pd.get_dummies(df_teams_2019, prefix = ['Team_1', 'Team_2'], columns = ['Team_1', 'Team_2'])

# Extracting features by dropping the 'Winner' column
X = final.drop(['Winner'], axis = 1)

# Assigning the 'Winner' column as the target variable
y = final["Winner"]

# Splitting the data into training and testing sets using a test size of 20% and a random state of 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
final.head()
# Out:
#          Winner  Team_1_Afghanistan  Team_1_Afghanistan   Team_1_Australia  \
# 0  New Zealand                False                False             False
# 1   Bangladesh                False                False             False
# 2       England               False                False             False
# 3     Sri Lanka               False                False             False
# 4    Bangladesh               False                False             False
#
#    Team_1_Australia   Team_1_Bangladesh  Team_1_Bangladesh   Team_1_England  \
# 0              False              False               False            True
# 1              False               True               False           False
# 2              False              False               False            True
# 3              False              False               False           False
# 4              False               True               False           False
#
# ...

# %% [markdown]
# **Applying the Random Forest Classifier Algorithm**

# %%
# Import the Random Forest module from sklearn
from sklearn.ensemble import RandomForestClassifier

# Create a Random Forest classifier with a linear kernel
rf = RandomForestClassifier(n_estimators = 100, max_depth = 20,
                              random_state = 0)

# Fit the classifier on the training data
rf.fit(X_train, y_train)

# Make predictions on the test data
pred = rf.predict(X_test)

# Calculating the training set score
score = rf.score(X_train, y_train)

# Calculate the test set score
score2 = rf.score(X_test, y_test)

# Print the training set accuracy with 3 decimal places
print("Training set accuracy: ", '%.3f'%(score))

# Print the test set accuracy with 3 decimal places
print("Test set accuracy: ", '%.3f'%(score2))
# Out:
# Training set accuracy:  0.749
# Test set accuracy:  0.673

# %% [markdown]
# **Evaluating the Best Model on Test Data**

# %%
# Read the ICC rankings from the 'ICC_Ranking.csv' file
ranking = pd.read_csv('/content/drive/MyDrive/Colab_Notebook/Internship_Name/Mentorness/File_Name/ICC_ranking_dataset.csv')

# Read the fixtures from the 'Fixtures.csv' file
fixtures = pd.read_csv('/content/drive/MyDrive/Colab_Notebook/Internship_Name/Mentorness/File_Name/Fixtures_dataset.csv')

# Initialize an empty list to store prediction results
pred_set = []

# %%
# Reset the DataFrame by dropping existing columns before insertion
fixtures = fixtures.drop(['first_position', 'second_position'], axis=1, errors='ignore')

# Insert team rankings for the 'Team_1' column
fixtures.insert(1, 'first_position', fixtures['Team_1'].map(ranking.set_index('Team_name')['Team_ranking']))

# Insert team rankings for the 'Team_2' column
fixtures.insert(2, 'second_position', fixtures['Team_2'].map(ranking.set_index('Team_name')['Team_ranking']))

# Select the first 45 rows of the updated fixtures DataFrame
fixtures = fixtures.iloc[:45, :]

# Display the first few rows of the updated DataFrame
fixtures.head()
# Out:
#   Round_number  first_position  second_position        Team_1       Team_2  \
# 0            1             5.0              NaN       England  New Zealand
# 1            1             NaN             10.0     Pakistan   Netherlands
# 2            1             7.0              8.0    Bangladesh  Afghanistan
# 3            1             6.0              9.0  South Africa    Sri Lanka
# 4            1             3.0              1.0         India    Australia
#
#         Date                                           Location    Group  \
# 0  5/10/2023                   Narendra Modi Stadium, Ahmedabad  Group A
# 1  6/10/2023      Rajiv Gandhi International Stadium, Hyderabad  Group A
# 2  7/10/2023  Himachal Pradesh Cricket Association Stadium, ...  Group A
# 3  7/10/2023                        Arun Jaitley Stadium, Delhi  Group A
# 4  8/10/2023                    MA Chidambaram Stadium, Chennai  Group A
#
#    Result
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# Filling missing values in the 'first_position' and 'second_position' columns with their respective means
fixtures['first_position'] = fixtures['first_position'].fillna(fixtures['first_position'].mean())
fixtures['second_position'] = fixtures['second_position'].fillna(fixtures['second_position'].mean())
fixtures.head()
# Out:
#   Round_number  first_position  second_position        Team_1       Team_2  \
# 0            1        5.000000         7.119048       England  New Zealand
# 1            1        4.411765        10.000000     Pakistan   Netherlands
# 2            1        7.000000         8.000000    Bangladesh  Afghanistan
# 3            1        6.000000         9.000000  South Africa    Sri Lanka
# 4            1        3.000000         1.000000         India    Australia
#
#         Date                                           Location    Group  \
# 0  5/10/2023                   Narendra Modi Stadium, Ahmedabad  Group A
# 1  6/10/2023      Rajiv Gandhi International Stadium, Hyderabad  Group A
# 2  7/10/2023  Himachal Pradesh Cricket Association Stadium, ...  Group A
# 3  7/10/2023                        Arun Jaitley Stadium, Delhi  Group A
# 4  8/10/2023                    MA Chidambaram Stadium, Chennai  Group A
#
#    Result
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# Creating an empty list to store predictions
pred_set = []

# Predicting winning teams based on positions in fixtures
for index, row in fixtures.iterrows():
    if row['first_position'] < row['second_position']:
        pred_set.append({'Team_1': row['Team_1'], 'Team_2': row['Team_2'], 'winning_team': None})
    else:
        pred_set.append({'Team_1': row['Team_2'], 'Team_2': row['Team_1'], 'winning_team': None})

# Creating a DataFrame for pred_set
pred_set = pd.DataFrame(pred_set)

# Creating a backup of the pred_set DataFrame
backup_pred_set = pred_set

# Displaying the first few rows of the pred_set DataFrame
pred_set.head()
# Out:
#          Team_1       Team_2 winning_team
# 0       England  New Zealand         None
# 1     Pakistan   Netherlands         None
# 2    Bangladesh  Afghanistan         None
# 3  South Africa    Sri Lanka         None
# 4     Australia        India         None

# %%
# Transforming the dataset using one-hot encoding for the 'Team_1' and 'Team_2' columns
pred_set = pd.get_dummies(pred_set, prefix = ['Team_1', 'Team_2'], columns = ['Team_1', 'Team_2'])

# Finding missing columns in the final dataset compared to the transformed 'pred_set'
missing_cols = set(final.columns) - set(pred_set.columns)

# Setting the missing columns in the 'pred_set' DataFrame to 0 and then keeping only the columns present in the 'final' DataFrame
for c in missing_cols:
    pred_set[c] = 0
pred_set = pred_set[final.columns]

# Dropping the 'Winner' column from 'pred_set'
pred_set = pred_set.drop(['Winner'], axis = 1)
pred_set.head()
# Out:
#    Team_1_Afghanistan  Team_1_Afghanistan   Team_1_Australia  \
# 0               False                    0             False
# 1               False                    0             False
# 2               False                    0             False
# 3               False                    0             False
# 4               False                    0              True
#
#    Team_1_Australia   Team_1_Bangladesh  Team_1_Bangladesh   Team_1_England  \
# 0                  0              False                   0            True
# 1                  0              False                   0           False
# 2                  0               True                   0           False
# 3                  0              False                   0           False
# 4                  0              False                   0           False
#
#    Team_1_England   Team_1_Hong Kong  Team_1_Hong Kong   ...  Team_2_India  \
# ...

# %% [markdown]
# **Interpret the Model Results**

# %%
# Making predictions using 'rf' on 'pred_set' and printing the winners for each fixture based on the prediction
predictions = rf.predict(pred_set)
for i in range(fixtures.shape[0]):
    print(backup_pred_set.iloc[i, 1] + " vs " + backup_pred_set.iloc[i, 0])
    if predictions[i] == 1:
        print("Winner: " + backup_pred_set.iloc[i, 1])
    else:
        print("Winner: " + backup_pred_set.iloc[i, 0])
    print("")
# Out:
# New Zealand vs England
# Winner: England
#
# Netherlands vs Pakistan
# Winner: Pakistan
#
# Afghanistan vs Bangladesh
# Winner: Bangladesh
#
# Sri Lanka vs South Africa
# Winner: South Africa
#
# India vs Australia
# Winner: Australia
#
# Netherlands vs New Zealand
# Winner: New Zealand
#
# Bangladesh vs England
# Winner: England
#
# Afghanistan vs India
# Winner: India
#
# Sri Lanka vs Pakistan
# Winner: Pakistan
#
# South Africa vs Australia
# Winner: Australia
#
# Bangladesh vs New Zealand
# Winner: New Zealand
#
# Afghanistan vs England
# Winner: England
#
# India vs Pakistan
# Winner: Pakistan
#
# Sri Lanka vs Australia
# Winner: Australia
#
# Netherlands vs South Africa
# Winner: South Africa
#
# Afghanistan vs New Zealand
# Winner: New Zealand
#
# Bangladesh vs India
# Winner: India
#
# Pakistan vs Australia
# Winner: Australia
#
# Netherlands vs Sri Lanka
# Winner: Sri Lanka
#
# South Africa vs England
# Winner: England
#
# New Zealand vs India
# Winner: India
#
# ...

# %%
# The teams qualified for the semi-finals based on wins
semi = [('Pakistan', 'Australia'),
            ('England', 'India')]

# %%
def clean_and_predict(matches, ranking, final, rf):
    # Initialize an empty list to store the positions of teams in the ranking
    positions = []

    # Loop through the list of matches and add the rankings of the teams to the positions list
    for match in matches:
        positions.append(ranking.loc[ranking['Team_name'] == match[0], 'Team_ranking'].iloc[0])
        positions.append(ranking.loc[ranking['Team_name'] == match[0], 'Team_ranking'].iloc[0])

    # Initialize an empty list to store the match predictions
    pred_set = []

    # Initialize indices i and j to 0 for iteration
    i = 0
    j = 0

    # Loop through the positions list to create match predictions
    while i < len(positions):
        dict1 = {}
        # Compare the positions of the two teams in the match and add the corresponding team names to the prediction dictionary
        if positions[i] < positions[i + 1]:
            dict1.update({'Team_1': matches[j][0], 'Team_2': matches[j][1]})
        else:
            dict1.update({'Team_1': matches[j][1], 'Team_2': matches[j][0]})

        # Add the prediction dictionary to the pred_set list
        pred_set.append(dict1)
        i += 2
        j += 1

    # Convert the pred_set list into a pandas DataFrame
    pred_set = pd.DataFrame(pred_set)

    # Make a backup of the pred_set DataFrame
    backup_pred_set = pred_set

    # Convert categorical variables in the pred_set DataFrame into dummy variables
    pred_set = pd.get_dummies(pred_set, prefix = ['Team_1', 'Team_2'], columns = ['Team_1', 'Team_2'])

    # Identify missing columns in 'pred_set' compared to the final DataFrame
    missing_cols2 = set(final.columns) - set(pred_set.columns)

    # Add the missing columns to the 'pred_set' DataFrame and set their values to 0
    for c in missing_cols2:
        pred_set[c] = 0

    # Reorder 'pred_set' columns to match the final DataFrame's order
    pred_set = pred_set[final.columns]

    # Drop the 'Winner' column from the 'pred_set' DataFrame
    pred_set = pred_set.drop(['Winner'], axis = 1)

    # Use the provided classifier (cls) to make predictions on the 'pred_set' DataFrame
    predictions = rf.predict(pred_set)

    # Loop through the 'pred_set' DataFrame and print the match predictions and winners
    for i in range(len(pred_set)):
        print(backup_pred_set.iloc[i, 1] + " vs " + backup_pred_set.iloc[i, 0])
        if predictions[i] == 1:
            print("Winner: " + backup_pred_set.iloc[i, 1])
        else:
            print("Winner: " + backup_pred_set.iloc[i, 0])
        print("")

# Call the clean_and_predict function with the provided arguments
clean_and_predict(semi, ranking, final, rf)
# Out:
# Pakistan vs Australia
# Winner: Australia
#
# England vs India
# Winner: India

# %%
# The teams qualified for the finals
finals = [('Australia', 'India')]

# %% [markdown]
# **Conclusion**

# %%
# Clean the data, apply ranking, and use the classifier to predict the outcome
clean_and_predict(finals, ranking, final, rf)
# Out:
# Australia vs India
# Winner: India
